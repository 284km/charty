# %%
require 'charty'
charty = Charty::Main.new(Charty::Rubyplot.new)
# Out:
# #<Charty::Main:0x00007fb45793c430 @frontend=#<Charty::Rubyplot:0x00007fb45793c458 @plot=Rubyplot>>

# %%
scatter = charty.scatter do
  series 0..10, (0..1).step(0.1)
  range x: 0..10, y: -1..1
end
scatter.render
# Out:
#  PNG 800x600 PseudoClass 144c 16-bit 6kb
